# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

from fuzzywuzzy import fuzz, process

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## Import Data

# %% [markdown]
# ## Analysis

# %%
sort.sort_values('Active_per_Cap').plot.bar(x="Country/Region", y="Active_per_Cap", figsize=(13,7))

# %%
fig = px.bar(agg.sort_values('Confirmed', ascending=False), x='Country/Region', y='Confirmed', height=650, title='Confirmed', color = 'Country/Region')
fig.show()

# %%
temp = agg.groupby('Date')['Recovered', 'Deaths', 'Active'].sum().reset_index()
temp = temp.melt(id_vars="Date", value_vars=['Recovered', 'Deaths', 'Active'],
                 var_name='Case', value_name='Count')
temp.head()

fig = px.area(temp, x="Date", y="Count", color='Case',
             title='Cases over time', color_discrete_sequence = [rec, dth, act])
fig.show()
